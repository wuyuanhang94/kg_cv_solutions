# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train17_f3/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
df
# Out:
#     train/box_loss  train/seg_loss  val/box_loss  val/seg_loss  \
# 0           1.5268          2.3592        1.5292        2.2097
# 1           1.4647          1.9887        1.7223        2.6334
# 2           1.4756          2.0194        1.5846        2.1707
# 3           1.4564          2.0026        1.5919        2.1136
# 4           1.4277          1.9687        1.5436        2.1076
# 5           1.4120          1.9487        1.5418        2.1053
# 6           1.4091          1.9318        1.5366        2.0871
# 7           1.3858          1.9089        1.5360        2.0422
# 8           1.3985          1.8976        1.5829        2.1367
# 9           1.3565          1.8592        1.5384        2.0277
# 10          1.3393          1.8655        1.5296        2.0173
# 11          1.3328          1.8515        1.5353        2.0750
# 12          1.3159          1.8253        1.5234        2.0489
# 13          1.3043          1.8102        1.5498        2.0185
# ...

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train3_f0/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
df
# Out:
#     train/box_loss  train/seg_loss  val/box_loss  val/seg_loss  \
# 0           1.5531          2.3937        1.4968        2.0408
# 1           1.4502          1.9845        1.4975        2.0415
# 2           1.4418          1.9728        1.5219        2.1795
# 3           1.4403          1.9727        1.5779        2.2059
# 4           1.4045          1.9336        1.5295        2.0852
# 5           1.3941          1.8957        1.5039        2.1012
# 6           1.3947          1.9367        1.5343        2.0394
# 7           1.3684          1.8905        1.5150        1.9965
# 8           1.3613          1.8830        1.5030        2.0039
# 9           1.3439          1.8658        1.5082        1.9794
# 10          1.3380          1.8251        1.5344        2.0666
# 11          1.3217          1.8243        1.4876        1.9408
# 12          1.3185          1.8258        1.4797        1.9302
# 13          1.3027          1.8074        1.4958        1.9674
# ...

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train17_f3/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
# Out:
# <Axes: >

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train16_f2/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
# Out:
# <Axes: >

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train4_f1/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#     train/box_loss  train/seg_loss  val/box_loss  val/seg_loss  \
# 0           1.5613          2.3979        1.4827        1.9903
# 1           1.4532          1.9926        1.4514        2.0605
# 2           1.4497          1.9877        1.4624        1.9414
# 3           1.4332          1.9552        1.5354        2.0119
# 4           1.4114          1.9414        1.4817        2.0253
# 5           1.4173          1.9358        1.5161        1.9957
# 6           1.4004          1.9343        1.6030        2.3135
# 7           1.3823          1.8870        1.4764        1.9349
# 8           1.3588          1.8829        1.4775        1.9254
# 9           1.3597          1.8506        1.4822        2.0247
# 10          1.3514          1.8459        1.4734        1.9308
# 11          1.3301          1.8324        1.4577        1.9219
# 12          1.3162          1.8319        1.4770        1.9491
# 13          1.3009          1.7928        1.4610        1.8759
#
# ...

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/kg_yolo/yolov8/runs/segment/train3_f0/results.csv")
df = df[['train/box_loss', 'train/seg_loss', 'train/cls_loss', 'train/dfl_loss', 'val/box_loss', 'val/seg_loss', 'val/cls_loss', 'val/dfl_loss', 'metrics/mAP50-95(M)']]
df = df[['train/box_loss', 'train/seg_loss', 'val/box_loss', 'val/seg_loss', 'metrics/mAP50-95(M)']]
df["metrics/mAP50-95(M)"] *= 10
df.plot(figsize=(10, 10), grid='open')
# Out:
# <Axes: >
