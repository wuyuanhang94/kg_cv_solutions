# %%
import numpy as np
import pandas as pd
pd.options.plotting.backend = "plotly"
import random
from glob import glob
import os, shutil
from tqdm.notebook import tqdm
tqdm.pandas()
import time
import copy
import joblib
import gc
from IPython import display as ipd
from joblib import Parallel, delayed

# visualization
import cv2
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import tensorflow as tf

IMG_SIZE = [320, 384]

def load_img(path, size=IMG_SIZE):
    img = cv2.imread(path, cv2.IMREAD_UNCHANGED)
    shape0 = np.array(img.shape[:2])
    resize = np.array(size)
    if np.any(shape0!=resize):
        diff = resize - shape0
        pad0 = diff[0]
        pad1 = diff[1]
        pady = [pad0//2, pad0//2 + pad0%2]
        padx = [pad1//2, pad1//2 + pad1%2]
        img = np.pad(img, [pady, padx])
        img = img.reshape((*resize))
        
#     img = np.tile(img[...,None], [1, 1, 3]) # gray to rgb
#     img = img.astype('float32') # original is uint16
#     mx = np.max(img)
#     if mx:
#         img/=mx # scale image to [0, 1]
    return img

def load_msk(path, size=IMG_SIZE):
    msk = np.load(path)
#     msk = msk.astype('float32')
#     msk/=255.0
#     msk = cv2.resize(msk, dsize=size, interpolation=cv2.INTER_NEAREST)
    shape0 = np.array(msk.shape[:2])
    resize = np.array(size)
    if np.any(shape0!=resize):
        diff = resize - shape0
        pad0 = diff[0]
        pad1 = diff[1]
        pady = [pad0//2, pad0//2 + pad0%2]
        padx = [pad1//2, pad1//2 + pad1%2]
        msk = np.pad(msk, [pady, padx, [0,0]])
        msk = msk.reshape((*resize, 3))
    return msk

def show_img(img, mask=None):
    plt.imshow(img, cmap='bone')
    
    if mask is not None:
        # plt.imshow(np.ma.masked_where(mask!=1, mask), alpha=0.5, cmap='autumn')
        plt.imshow(mask, alpha=0.5)
        handles = [Rectangle((0,0),1,1, color=_c) for _c in [(0.667,0.0,0.0), (0.0,0.667,0.0), (0.0,0.0,0.667)]]
        labels = [ "Large Bowel", "Small Bowel", "Stomach"]
        plt.legend(handles,labels)
    plt.axis('off')
    
def load_imgs(img_paths, size=IMG_SIZE):
    imgs = np.zeros((*size, len(img_paths)), dtype=np.uint16)
    for i, img_path in enumerate(img_paths):
        img = load_img(img_path, size=size)
        imgs[..., i]+=img
    return imgs

# %%
df = pd.read_csv('/home/yiw/gi/train_step0.csv')
df['segmentation'] = df.segmentation.fillna('')
df['rle_len'] = df.segmentation.map(len) # length of each rle mask
df['mask_path'] = df.mask_path.str.replace('/png/','/np/').str.replace('.png','.npy')

df2 = df.groupby(['id'])['segmentation'].agg(list).to_frame().reset_index() # rle list of each id
df2 = df2.merge(df.groupby(['id'])['rle_len'].agg(sum).to_frame().reset_index()) # total length of all rles of each id

df = df.drop(columns=['segmentation', 'class', 'rle_len'])
df = df.groupby(['id']).head(1).reset_index(drop=True)
df = df.merge(df2, on=['id'])
df['empty'] = (df.rle_len==0) # empty masks
df.head(199)
# Out:
# <ipython-input-2-d990053b069b>:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['mask_path'] = df.mask_path.str.replace('/png/','/np/').str.replace('.png','.npy')
#                            id  case  day  slice  \
# 0    case123_day20_slice_0001   123   20      1
# 1    case123_day20_slice_0002   123   20      2
# 2    case123_day20_slice_0003   123   20      3
# 3    case123_day20_slice_0004   123   20      4
# 4    case123_day20_slice_0005   123   20      5
# ..                        ...   ...  ...    ...
# 194  case123_day22_slice_0051   123   22     51
# 195  case123_day22_slice_0052   123   22     52
# 196  case123_day22_slice_0053   123   22     53
# 197  case123_day22_slice_0054   123   22     54
# 198  case123_day22_slice_0055   123   22     55
#
#                                             image_path  height  width  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 1    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 2    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 3    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 4    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# ..                                                 ...     ...    ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 195  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 196  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 197  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 198  /home/yiw/gi/input/train/case123/case123_day22...     266    266
#
#                                              mask_path segmentation  rle_len  \
# 0    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 1    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 2    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 3    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 4    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# ..                                                 ...          ...      ...
# 194  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 195  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 196  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 197  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 198  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
#
#      empty
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# ..     ...
# 194   True
# 195   True
# 196   True
# 197   True
# 198   True
#
# [199 rows x 11 columns]

# %%
channels=5
stride=1
for i in range(channels):
    # 0, -1, -2, -3, -4
    # 2, 1, 0, -1 , -2
    df[f'image_path_{i:02}'] = df.groupby(['case','day'])['image_path'].shift(-i*stride+2).fillna(method="bfill").fillna(method="ffill")
df['image_paths'] = df[[f'image_path_{i:02d}' for i in range(channels)]].values.tolist()
df.image_paths.tolist()[0]
# Out:
# ['/home/yiw/gi/input/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png',
#  '/home/yiw/gi/input/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png',
#  '/home/yiw/gi/input/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png',
#  '/home/yiw/gi/input/train/case123/case123_day20/scans/slice_0002_266_266_1.50_1.50.png',
#  '/home/yiw/gi/input/train/case123/case123_day20/scans/slice_0003_266_266_1.50_1.50.png']

# %%
row=1; col=4
plt.figure(figsize=(5*col,5*row))
for i, id_ in enumerate(df[df['empty']==0].sample(frac=1.0)['id'].unique()[:row*col]):
    idf = df[df['id']==id_]
    img = load_img(idf.image_path.iloc[0])
    mask = load_msk(idf.mask_path.iloc[0])
    plt.subplot(row, col, i+1)
    i+=1
    show_img(img, mask=mask)
    plt.tight_layout()

# %%
idx = 40

plt.figure(figsize=(20, 10))

plt.subplot(1, 2, 1)
img = load_img(df.image_path[idx]).astype('float32')
img/=img.max()
plt.imshow(img)
plt.axis('off')

plt.subplot(1, 2, 2)
imgs = load_imgs(df.image_paths[idx]).astype('float32')
imgs/=imgs.max(axis=(0,1))
plt.imshow(imgs[..., 1:4])
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
IMAGE_DIR = '/tmp/images'
MASK_DIR = '/tmp/masks'
# !mkdir -p $IMAGE_DIR && mkdir -p $MASK_DIR

def save_mask(id_):
    row = df[df['id']==id_].squeeze()
    
    img_paths = row.image_paths
    imgs = load_imgs(img_paths)
    np.save(f'{IMAGE_DIR}/{id_}.npy', imgs)
    
    msk_path = row.mask_path
    msk = load_msk(msk_path)
    np.save(f'{MASK_DIR}/{id_}.npy', msk)
    
    return

ids = df['id'].unique()
_ = Parallel(n_jobs=-1, backend='threading')(delayed(save_mask)(id_)\
                                             for id_ in tqdm(ids, total=len(ids)))
# 把 images 和 masks 文件夹拷贝到 ~/gi/input/
# Out:
#   0%|          | 0/38496 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(15, 5))

imgs = np.load(f'{IMAGE_DIR}/case123_day0_slice_0080.npy').astype('float32')
imgs/=imgs.max(axis=(0,1))

plt.subplot(1, 3, 1)
plt.imshow(imgs[..., 1:4])

msk = np.load(f'{MASK_DIR}/case123_day0_slice_0080.npy').astype('float32')
msk/=255.0

plt.subplot(1, 3, 2)
plt.imshow(msk)


plt.subplot(1, 3, 3)
plt.imshow(imgs[..., 1:4])
plt.imshow(msk, alpha=0.5)

# %%
df.to_csv('train_step1.csv', index=False)
df.head(199)
# Out:
#                            id  case  day  slice  \
# 0    case123_day20_slice_0001   123   20      1
# 1    case123_day20_slice_0002   123   20      2
# 2    case123_day20_slice_0003   123   20      3
# 3    case123_day20_slice_0004   123   20      4
# 4    case123_day20_slice_0005   123   20      5
# ..                        ...   ...  ...    ...
# 194  case123_day22_slice_0051   123   22     51
# 195  case123_day22_slice_0052   123   22     52
# 196  case123_day22_slice_0053   123   22     53
# 197  case123_day22_slice_0054   123   22     54
# 198  case123_day22_slice_0055   123   22     55
#
#                                             image_path  height  width  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 1    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 2    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 3    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 4    /home/yiw/gi/input/train/case123/case123_day20...     266    266
# ..                                                 ...     ...    ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 195  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 196  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 197  /home/yiw/gi/input/train/case123/case123_day22...     266    266
# 198  /home/yiw/gi/input/train/case123/case123_day22...     266    266
#
#                                              mask_path segmentation  rle_len  \
# 0    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 1    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 2    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 3    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 4    /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# ..                                                 ...          ...      ...
# 194  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 195  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 196  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 197  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
# 198  /home/yiw/gi/input/np/train/case123/case123_da...       [, , ]        0
#
#      empty                                      image_path_00  \
# 0     True  /home/yiw/gi/input/train/case123/case123_day20...
# 1     True  /home/yiw/gi/input/train/case123/case123_day20...
# 2     True  /home/yiw/gi/input/train/case123/case123_day20...
# 3     True  /home/yiw/gi/input/train/case123/case123_day20...
# 4     True  /home/yiw/gi/input/train/case123/case123_day20...
# ..     ...                                                ...
# 194   True  /home/yiw/gi/input/train/case123/case123_day22...
# 195   True  /home/yiw/gi/input/train/case123/case123_day22...
# 196   True  /home/yiw/gi/input/train/case123/case123_day22...
# 197   True  /home/yiw/gi/input/train/case123/case123_day22...
# 198   True  /home/yiw/gi/input/train/case123/case123_day22...
#
#                                          image_path_01  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...
# 1    /home/yiw/gi/input/train/case123/case123_day20...
# 2    /home/yiw/gi/input/train/case123/case123_day20...
# 3    /home/yiw/gi/input/train/case123/case123_day20...
# 4    /home/yiw/gi/input/train/case123/case123_day20...
# ..                                                 ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...
# 195  /home/yiw/gi/input/train/case123/case123_day22...
# 196  /home/yiw/gi/input/train/case123/case123_day22...
# 197  /home/yiw/gi/input/train/case123/case123_day22...
# 198  /home/yiw/gi/input/train/case123/case123_day22...
#
#                                          image_path_02  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...
# 1    /home/yiw/gi/input/train/case123/case123_day20...
# 2    /home/yiw/gi/input/train/case123/case123_day20...
# 3    /home/yiw/gi/input/train/case123/case123_day20...
# 4    /home/yiw/gi/input/train/case123/case123_day20...
# ..                                                 ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...
# 195  /home/yiw/gi/input/train/case123/case123_day22...
# 196  /home/yiw/gi/input/train/case123/case123_day22...
# 197  /home/yiw/gi/input/train/case123/case123_day22...
# 198  /home/yiw/gi/input/train/case123/case123_day22...
#
#                                          image_path_03  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...
# 1    /home/yiw/gi/input/train/case123/case123_day20...
# 2    /home/yiw/gi/input/train/case123/case123_day20...
# 3    /home/yiw/gi/input/train/case123/case123_day20...
# 4    /home/yiw/gi/input/train/case123/case123_day20...
# ..                                                 ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...
# 195  /home/yiw/gi/input/train/case123/case123_day22...
# 196  /home/yiw/gi/input/train/case123/case123_day22...
# 197  /home/yiw/gi/input/train/case123/case123_day22...
# 198  /home/yiw/gi/input/train/case123/case123_day22...
#
#                                          image_path_04  \
# 0    /home/yiw/gi/input/train/case123/case123_day20...
# 1    /home/yiw/gi/input/train/case123/case123_day20...
# 2    /home/yiw/gi/input/train/case123/case123_day20...
# 3    /home/yiw/gi/input/train/case123/case123_day20...
# 4    /home/yiw/gi/input/train/case123/case123_day20...
# ..                                                 ...
# 194  /home/yiw/gi/input/train/case123/case123_day22...
# 195  /home/yiw/gi/input/train/case123/case123_day22...
# 196  /home/yiw/gi/input/train/case123/case123_day22...
# 197  /home/yiw/gi/input/train/case123/case123_day22...
# 198  /home/yiw/gi/input/train/case123/case123_day22...
#
#                                            image_paths
# 0    [/home/yiw/gi/input/train/case123/case123_day2...
# 1    [/home/yiw/gi/input/train/case123/case123_day2...
# 2    [/home/yiw/gi/input/train/case123/case123_day2...
# 3    [/home/yiw/gi/input/train/case123/case123_day2...
# 4    [/home/yiw/gi/input/train/case123/case123_day2...
# ..                                                 ...
# 194  [/home/yiw/gi/input/train/case123/case123_day2...
# 195  [/home/yiw/gi/input/train/case123/case123_day2...
# 196  [/home/yiw/gi/input/train/case123/case123_day2...
# 197  [/home/yiw/gi/input/train/case123/case123_day2...
# 198  [/home/yiw/gi/input/train/case123/case123_day2...
#
# [199 rows x 17 columns]

# %%
import pandas as pd

df = pd.read_csv("/home/yiw/gi/train_step1.csv")
df
# Out:
#                              id  case  day  slice  \
# 0      case123_day20_slice_0001   123   20      1
# 1      case123_day20_slice_0002   123   20      2
# 2      case123_day20_slice_0003   123   20      3
# 3      case123_day20_slice_0004   123   20      4
# 4      case123_day20_slice_0005   123   20      5
# ...                         ...   ...  ...    ...
# 38491    case30_day0_slice_0140    30    0    140
# 38492    case30_day0_slice_0141    30    0    141
# 38493    case30_day0_slice_0142    30    0    142
# 38494    case30_day0_slice_0143    30    0    143
# 38495    case30_day0_slice_0144    30    0    144
#
#                                               image_path  height  width  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 1      /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 2      /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 3      /home/yiw/gi/input/train/case123/case123_day20...     266    266
# 4      /home/yiw/gi/input/train/case123/case123_day20...     266    266
# ...                                                  ...     ...    ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...     266    266
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...     266    266
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...     266    266
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...     266    266
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...     266    266
#
#                                                mask_path  segmentation  \
# 0      /home/yiw/gi/input/np/train/case123/case123_da...  ['', '', '']
# 1      /home/yiw/gi/input/np/train/case123/case123_da...  ['', '', '']
# 2      /home/yiw/gi/input/np/train/case123/case123_da...  ['', '', '']
# 3      /home/yiw/gi/input/np/train/case123/case123_da...  ['', '', '']
# 4      /home/yiw/gi/input/np/train/case123/case123_da...  ['', '', '']
# ...                                                  ...           ...
# 38491  /home/yiw/gi/input/np/train/case30/case30_day0...  ['', '', '']
# 38492  /home/yiw/gi/input/np/train/case30/case30_day0...  ['', '', '']
# 38493  /home/yiw/gi/input/np/train/case30/case30_day0...  ['', '', '']
# 38494  /home/yiw/gi/input/np/train/case30/case30_day0...  ['', '', '']
# 38495  /home/yiw/gi/input/np/train/case30/case30_day0...  ['', '', '']
#
#        rle_len  ...                                      image_path_00  \
# 0            0  ...  /home/yiw/gi/input/train/case123/case123_day20...
# 1            0  ...  /home/yiw/gi/input/train/case123/case123_day20...
# 2            0  ...  /home/yiw/gi/input/train/case123/case123_day20...
# 3            0  ...  /home/yiw/gi/input/train/case123/case123_day20...
# 4            0  ...  /home/yiw/gi/input/train/case123/case123_day20...
# ...        ...  ...                                                ...
# 38491        0  ...  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492        0  ...  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493        0  ...  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494        0  ...  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495        0  ...  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_01  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_02  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_03  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_04  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_05  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_06  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_07  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                            image_path_08  \
# 0      /home/yiw/gi/input/train/case123/case123_day20...
# 1      /home/yiw/gi/input/train/case123/case123_day20...
# 2      /home/yiw/gi/input/train/case123/case123_day20...
# 3      /home/yiw/gi/input/train/case123/case123_day20...
# 4      /home/yiw/gi/input/train/case123/case123_day20...
# ...                                                  ...
# 38491  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38492  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38493  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38494  /home/yiw/gi/input/train/case30/case30_day0/sc...
# 38495  /home/yiw/gi/input/train/case30/case30_day0/sc...
#
#                                              image_paths
# 0      ['/home/yiw/gi/input/train/case123/case123_day...
# 1      ['/home/yiw/gi/input/train/case123/case123_day...
# 2      ['/home/yiw/gi/input/train/case123/case123_day...
# 3      ['/home/yiw/gi/input/train/case123/case123_day...
# 4      ['/home/yiw/gi/input/train/case123/case123_day...
# ...                                                  ...
# 38491  ['/home/yiw/gi/input/train/case30/case30_day0/...
# 38492  ['/home/yiw/gi/input/train/case30/case30_day0/...
# 38493  ['/home/yiw/gi/input/train/case30/case30_day0/...
# 38494  ['/home/yiw/gi/input/train/case30/case30_day0/...
# 38495  ['/home/yiw/gi/input/train/case30/case30_day0/...
#
# [38496 rows x 21 columns]

# %%
df.height.unique()
# Out:
# array([266, 310, 234, 276])

# %%
df.width.unique()
# Out:
# array([266, 360, 234, 276])

# %%
pd.options.display.max_seq_items = 2000
pd.set_option("max_colwidth", None)

df.image_paths.iloc[-4]
# Out:
# "['/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0137_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0138_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0139_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0140_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0141_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0142_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0143_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0144_266_266_1.50_1.50.png', '/home/yiw/gi/input/train/case30/case30_day0/scans/slice_0144_266_266_1.50_1.50.png']"

# %%
df.image_path
# Out:
# 0        /home/yiw/gi/input/train/case123/case123_day20/scans/slice_0001_266_266_1.50_1.50.png
# 1        /home/yiw/gi/input/train/case123/case123_day20/scans/slice_0002_266_266_1.50_1.50.png
# 2        /home/yiw/gi/input/train/case123/case123_day20/scans/slice_0003_266_266_1.50_1.50.png
# 3        /home/yiw/gi/input/train/case123/case123_day20/scans/slice_0004_266_266_1.50_1.50.png
# 4        /home/yiw/gi/input/train/case123/case123_day20/scans/slice_0005_266_266_1.50_1.50.png
#                                                  ...
# 38491       /home/yiw/gi/input/train/case30/case30_day0/scans/slice_0140_266_266_1.50_1.50.png
# 38492       /home/yiw/gi/input/train/case30/case30_day0/scans/slice_0141_266_266_1.50_1.50.png
# 38493       /home/yiw/gi/input/train/case30/case30_day0/scans/slice_0142_266_266_1.50_1.50.png
# 38494       /home/yiw/gi/input/train/case30/case30_day0/scans/slice_0143_266_266_1.50_1.50.png
# 38495       /home/yiw/gi/input/train/case30/case30_day0/scans/slice_0144_266_266_1.50_1.50.png
# Name: image_path, Length: 38496, dtype: object

# %%
pd.set_option('display.max_rows', None)
df.mask_path[64:99]
# Out:
# 64    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0065_266_266_1.50_1.50.npy
# 65    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0066_266_266_1.50_1.50.npy
# 66    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0067_266_266_1.50_1.50.npy
# 67    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0068_266_266_1.50_1.50.npy
# 68    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0069_266_266_1.50_1.50.npy
# 69    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0070_266_266_1.50_1.50.npy
# 70    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0071_266_266_1.50_1.50.npy
# 71    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0072_266_266_1.50_1.50.npy
# 72    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0073_266_266_1.50_1.50.npy
# 73    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0074_266_266_1.50_1.50.npy
# 74    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0075_266_266_1.50_1.50.npy
# 75    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0076_266_266_1.50_1.50.npy
# 76    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0077_266_266_1.50_1.50.npy
# 77    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0078_266_266_1.50_1.50.npy
# 78    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0079_266_266_1.50_1.50.npy
# 79    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0080_266_266_1.50_1.50.npy
# 80    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0081_266_266_1.50_1.50.npy
# 81    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0082_266_266_1.50_1.50.npy
# 82    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0083_266_266_1.50_1.50.npy
# 83    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0084_266_266_1.50_1.50.npy
# 84    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0085_266_266_1.50_1.50.npy
# 85    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0086_266_266_1.50_1.50.npy
# 86    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0087_266_266_1.50_1.50.npy
# 87    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0088_266_266_1.50_1.50.npy
# 88    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0089_266_266_1.50_1.50.npy
# 89    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0090_266_266_1.50_1.50.npy
# 90    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0091_266_266_1.50_1.50.npy
# 91    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0092_266_266_1.50_1.50.npy
# 92    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0093_266_266_1.50_1.50.npy
# 93    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0094_266_266_1.50_1.50.npy
# 94    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0095_266_266_1.50_1.50.npy
# 95    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0096_266_266_1.50_1.50.npy
# 96    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0097_266_266_1.50_1.50.npy
# 97    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0098_266_266_1.50_1.50.npy
# 98    /home/yiw/gi/input/np/train/case123/case123_day20/scans/slice_0099_266_266_1.50_1.50.npy
# Name: mask_path, dtype: object
